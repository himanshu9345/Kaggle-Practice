# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
from os import path, listdir
import  cv2
from keras.preprocessing.image import ImageDataGenerator

# %%
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %%
# checking data
train.head(5)
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
# train_ID = train['image_id']
# test_ID = test['image_id']

# %%
# train.drop("image_id", axis = 1, inplace = True)
# test.drop("image_id", axis = 1, inplace = True)

# %%
'''
0 healthy
1 multiple_disease
2 rust
3 scab
'''  
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
# y_train = train.values

# %%
#  image folder path
path1 = "input\\resized_image"
# imagePaths = [path.join(path1, f) for f in listdir(path1)]
train_data = []
train_label= []

# %%
# %%time
for index, row in train.iterrows():
    print(index,row['image_id'])
    image = cv2.imread(path1+"\\"+row['image_id']+".jpg")
    train_data.append(image)
    train_label.append(row[1:])
# Out:
# 0 Train_0
# 1 Train_1
# 2 Train_2
# 3 Train_3
# 4 Train_4
# 5 Train_5
# 6 Train_6
# 7 Train_7
# 8 Train_8
# 9 Train_9
# 10 Train_10
# 11 Train_11
# 12 Train_12
# 13 Train_13
# 14 Train_14
# 15 Train_15
# 16 Train_16
# 17 Train_17
# 18 Train_18
# 19 Train_19
# 20 Train_20
# 21 Train_21
# 22 Train_22
# 23 Train_23
# 24 Train_24
# 25 Train_25
# 26 Train_26
# 27 Train_27
# 28 Train_28
# 29 Train_29
# 30 Train_30
# 31 Train_31
# 32 Train_32
# 33 Train_33
# 34 Train_34
# 35 Train_35
# 36 Train_36
# 37 Train_37
# 38 Train_38
# 39 Train_39
# 40 Train_40
# 41 Train_41
# 42 Train_42
# 43 Train_43
# 44 Train_44
# 45 Train_45
# 46 Train_46
# 47 Train_47
# 48 Train_48
# 49 Train_49
# 50 Train_50
# 51 Train_51
# 52 Train_52
# 53 Train_53
# 54 Train_54
# 55 Train_55
# 56 Train_56
# 57 Train_57
# 58 Train_58
# 59 Train_59
# 60 Train_60
# 61 Train_61
# 62 Train_62
# 63 Train_63
# 64 Train_64
# 65 Train_65
# 66 Train_66
# 67 Train_67
# 68 Train_68
# 69 Train_69
# 70 Train_70
# 71 Train_71
# 72 Train_72
# 73 Train_73
# 74 Train_74
# 75 Train_75
# 76 Train_76
# 77 Train_77
# 78 Train_78
# 79 Train_79
# 80 Train_80
# 81 Train_81
# 82 Train_82
# 83 Train_83
# 84 Train_84
# 85 Train_85
# 86 Train_86
# 87 Train_87
# 88 Train_88
# 89 Train_89
# 90 Train_90
# 91 Train_91
# 92 Train_92
# 93 Train_93
# 94 Train_94
# 95 Train_95
# 96 Train_96
# 97 Train_97
# 98 Train_98
# 99 Train_99
# 100 Train_100
# 101 Train_101
# 102 Train_102
# 103 Train_103
# 104 Train_104
# 105 Train_105
# 106 Train_106
# 107 Train_107
# 108 Train_108
# 109 Train_109
# 110 Train_110
# 111 Train_111
# 112 Train_112
# 113 Train_113
# 114 Train_114
# 115 Train_115
# 116 Train_116
# 117 Train_117
# 118 Train_118
# 119 Train_119
# 120 Train_120
# 121 Train_121
# 122 Train_122
# 123 Train_123
# 124 Train_124
# 125 Train_125
# 126 Train_126
# 127 Train_127
# 128 Train_128
# 129 Train_129
# 130 Train_130
# 131 Train_131
# 132 Train_132
# 133 Train_133
# 134 Train_134
# 135 Train_135
# 136 Train_136
# 137 Train_137
# 138 Train_138
# 139 Train_139
# 140 Train_140
# 141 Train_141
# 142 Train_142
# 143 Train_143
# 144 Train_144
# 145 Train_145
# 146 Train_146
# 147 Train_147
# 148 Train_148
# 149 Train_149
# 150 Train_150
# 151 Train_151
# 152 Train_152
# 153 Train_153
# 154 Train_154
# 155 Train_155
# 156 Train_156
# 157 Train_157
# 158 Train_158
# 159 Train_159
# 160 Train_160
# 161 Train_161
# 162 Train_162
# 163 Train_163
# 164 Train_164
# 165 Train_165
# 166 Train_166
# 167 Train_167
# 168 Train_168
# 169 Train_169
# 170 Train_170
# 171 Train_171
# 172 Train_172
# 173 Train_173
# 174 Train_174
# 175 Train_175
# 176 Train_176
# 177 Train_177
# 178 Train_178
# 179 Train_179
# 180 Train_180
# 181 Train_181
# 182 Train_182
# 183 Train_183
# 184 Train_184
# 185 Train_185
# 186 Train_186
# 187 Train_187
# 188 Train_188
# 189 Train_189
# 190 Train_190
# 191 Train_191
# 192 Train_192
# 193 Train_193
# 194 Train_194
# 195 Train_195
# 196 Train_196
# 197 Train_197
# 198 Train_198
# 199 Train_199
# 200 Train_200
# 201 Train_201
# 202 Train_202
# 203 Train_203
# 204 Train_204
# 205 Train_205
# 206 Train_206
# 207 Train_207
# 208 Train_208
# 209 Train_209
# 210 Train_210
# 211 Train_211
# 212 Train_212
# 213 Train_213
# 214 Train_214
# 215 Train_215
# 216 Train_216
# 217 Train_217
# 218 Train_218
# 219 Train_219
# 220 Train_220
# 221 Train_221
# 222 Train_222
# 223 Train_223
# 224 Train_224
# 225 Train_225
# 226 Train_226
# 227 Train_227
# 228 Train_228
# 229 Train_229
# 230 Train_230
# 231 Train_231
# 232 Train_232
# 233 Train_233
# 234 Train_234
# 235 Train_235
# 236 Train_236
# 237 Train_237
# 238 Train_238
# 239 Train_239
# 240 Train_240
# 241 Train_241
# 242 Train_242
# 243 Train_243
# 244 Train_244
# 245 Train_245
# 246 Train_246
# 247 Train_247
# 248 Train_248
# 249 Train_249
# 250 Train_250
# 251 Train_251
# 252 Train_252
# 253 Train_253
# 254 Train_254
# 255 Train_255
# 256 Train_256
# 257 Train_257
# 258 Train_258
# 259 Train_259
# 260 Train_260
# 261 Train_261
# 262 Train_262
# 263 Train_263
# 264 Train_264
# 265 Train_265
# 266 Train_266
# 267 Train_267
# 268 Train_268
# 269 Train_269
# 270 Train_270
# 271 Train_271
# 272 Train_272
# 273 Train_273
# 274 Train_274
# 275 Train_275
# 276 Train_276
# 277 Train_277
# 278 Train_278
# 279 Train_279
# 280 Train_280
# 281 Train_281
# 282 Train_282
# 283 Train_283
# 284 Train_284
# 285 Train_285
# 286 Train_286
# 287 Train_287
# 288 Train_288
# 289 Train_289
# 290 Train_290
# 291 Train_291
# 292 Train_292
# 293 Train_293
# 294 Train_294
# 295 Train_295
# 296 Train_296
# 297 Train_297
# 298 Train_298
# 299 Train_299
# 300 Train_300
# 301 Train_301
# 302 Train_302
# 303 Train_303
# 304 Train_304
# 305 Train_305
# 306 Train_306
# 307 Train_307
# 308 Train_308
# 309 Train_309
# 310 Train_310
# 311 Train_311
# 312 Train_312
# 313 Train_313
# 314 Train_314
# 315 Train_315
# 316 Train_316
# 317 Train_317
# 318 Train_318
# 319 Train_319
# 320 Train_320
# 321 Train_321
# 322 Train_322
# 323 Train_323
# 324 Train_324
# 325 Train_325
# 326 Train_326
# 327 Train_327
# 328 Train_328
# 329 Train_329
# 330 Train_330
# 331 Train_331
# 332 Train_332
# 333 Train_333
# 334 Train_334
# 335 Train_335
# 336 Train_336
# 337 Train_337
# 338 Train_338
# 339 Train_339
# 340 Train_340
# 341 Train_341
# 342 Train_342
# 343 Train_343
# 344 Train_344
# 345 Train_345
# 346 Train_346
# 347 Train_347
# 348 Train_348
# 349 Train_349
# 350 Train_350
# 351 Train_351
# 352 Train_352
# 353 Train_353
# 354 Train_354
# 355 Train_355
# 356 Train_356
# 357 Train_357
# 358 Train_358
# 359 Train_359
# 360 Train_360
# 361 Train_361
# 362 Train_362
# 363 Train_363
# 364 Train_364
# 365 Train_365
# 366 Train_366
# 367 Train_367
# 368 Train_368
# 369 Train_369
# 370 Train_370
# 371 Train_371
# 372 Train_372
# 373 Train_373
# 374 Train_374
# 375 Train_375
# 376 Train_376
# 377 Train_377
# 378 Train_378
# 379 Train_379
# 380 Train_380
# 381 Train_381
# 382 Train_382
# 383 Train_383
# 384 Train_384
# 385 Train_385
# 386 Train_386
# 387 Train_387
# 388 Train_388
# 389 Train_389
# 390 Train_390
# 391 Train_391
# 392 Train_392
# 393 Train_393
# 394 Train_394
# 395 Train_395
# 396 Train_396
# 397 Train_397
# 398 Train_398
# 399 Train_399
# 400 Train_400
# 401 Train_401
# 402 Train_402
# 403 Train_403
# 404 Train_404
# 405 Train_405
# 406 Train_406
# 407 Train_407
# 408 Train_408
# 409 Train_409
# 410 Train_410
# 411 Train_411
# 412 Train_412
# 413 Train_413
# 414 Train_414
# 415 Train_415
# 416 Train_416
# 417 Train_417
# 418 Train_418
# 419 Train_419
# 420 Train_420
# 421 Train_421
# 422 Train_422
# 423 Train_423
# 424 Train_424
# 425 Train_425
# 426 Train_426
# 427 Train_427
# 428 Train_428
# 429 Train_429
# 430 Train_430
# 431 Train_431
# 432 Train_432
# 433 Train_433
# 434 Train_434
# 435 Train_435
# 436 Train_436
# 437 Train_437
# 438 Train_438
# 439 Train_439
# 440 Train_440
# 441 Train_441
# 442 Train_442
# 443 Train_443
# 444 Train_444
# 445 Train_445
# 446 Train_446
# 447 Train_447
# 448 Train_448
# 449 Train_449
# 450 Train_450
# 451 Train_451
# 452 Train_452
# 453 Train_453
# 454 Train_454
# 455 Train_455
# 456 Train_456
# 457 Train_457
# 458 Train_458
# 459 Train_459
# 460 Train_460
# 461 Train_461
# 462 Train_462
# 463 Train_463
# 464 Train_464
# 465 Train_465
# 466 Train_466
# 467 Train_467
# 468 Train_468
# 469 Train_469
# 470 Train_470
# 471 Train_471
# 472 Train_472
# 473 Train_473
# 474 Train_474
# 475 Train_475
# 476 Train_476
# 477 Train_477
# 478 Train_478
# 479 Train_479
# 480 Train_480
# 481 Train_481
# 482 Train_482
# 483 Train_483
# 484 Train_484
# 485 Train_485
# 486 Train_486
# 487 Train_487
# 488 Train_488
# 489 Train_489
# 490 Train_490
# 491 Train_491
# 492 Train_492
# 493 Train_493
# 494 Train_494
# 495 Train_495
# 496 Train_496
# 497 Train_497
# 498 Train_498
# 499 Train_499
# 500 Train_500
# 501 Train_501
# 502 Train_502
# 503 Train_503
# 504 Train_504
# 505 Train_505
# 506 Train_506
# 507 Train_507
# 508 Train_508
# 509 Train_509
# 510 Train_510
# 511 Train_511
# 512 Train_512
# 513 Train_513
# 514 Train_514
# 515 Train_515
# 516 Train_516
# 517 Train_517
# 518 Train_518
# 519 Train_519
# 520 Train_520
# 521 Train_521
# 522 Train_522
# 523 Train_523
# 524 Train_524
# 525 Train_525
# 526 Train_526
# 527 Train_527
# 528 Train_528
# 529 Train_529
# 530 Train_530
# 531 Train_531
# 532 Train_532
# 533 Train_533
# 534 Train_534
# 535 Train_535
# 536 Train_536
# 537 Train_537
# 538 Train_538
# 539 Train_539
# 540 Train_540
# 541 Train_541
# 542 Train_542
# 543 Train_543
# 544 Train_544
# 545 Train_545
# 546 Train_546
# 547 Train_547
# 548 Train_548
# 549 Train_549
# 550 Train_550
# 551 Train_551
# 552 Train_552
# 553 Train_553
# 554 Train_554
# 555 Train_555
# 556 Train_556
# 557 Train_557
# 558 Train_558
# 559 Train_559
# 560 Train_560
# 561 Train_561
# 562 Train_562
# 563 Train_563
# 564 Train_564
# 565 Train_565
# 566 Train_566
# 567 Train_567
# 568 Train_568
# 569 Train_569
# 570 Train_570
# 571 Train_571
# 572 Train_572
# 573 Train_573
# 574 Train_574
# 575 Train_575
# 576 Train_576
# 577 Train_577
# 578 Train_578
# 579 Train_579
# 580 Train_580
# 581 Train_581
# 582 Train_582
# 583 Train_583
# 584 Train_584
# 585 Train_585
# 586 Train_586
# 587 Train_587
# 588 Train_588
# 589 Train_589
# 590 Train_590
# 591 Train_591
# 592 Train_592
# 593 Train_593
# 594 Train_594
# 595 Train_595
# 596 Train_596
# 597 Train_597
# 598 Train_598
# 599 Train_599
# 600 Train_600
# 601 Train_601
# 602 Train_602
# 603 Train_603
# 604 Train_604
# 605 Train_605
# 606 Train_606
# 607 Train_607
# 608 Train_608
# 609 Train_609
# 610 Train_610
# 611 Train_611
# 612 Train_612
# 613 Train_613
# 614 Train_614
# 615 Train_615
# 616 Train_616
# 617 Train_617
# 618 Train_618
# 619 Train_619
# 620 Train_620
# 621 Train_621
# 622 Train_622
# 623 Train_623
# 624 Train_624
# 625 Train_625
# 626 Train_626
# 627 Train_627
# 628 Train_628
# 629 Train_629
# 630 Train_630
# 631 Train_631
# 632 Train_632
# 633 Train_633
# 634 Train_634
# 635 Train_635
# 636 Train_636
# 637 Train_637
# 638 Train_638
# 639 Train_639
# 640 Train_640
# 641 Train_641
# 642 Train_642
# 643 Train_643
# 644 Train_644
# 645 Train_645
# 646 Train_646
# 647 Train_647
# 648 Train_648
# 649 Train_649
# 650 Train_650
# 651 Train_651
# 652 Train_652
# 653 Train_653
# 654 Train_654
# 655 Train_655
# 656 Train_656
# 657 Train_657
# 658 Train_658
# 659 Train_659
# 660 Train_660
# 661 Train_661
# 662 Train_662
# 663 Train_663
# 664 Train_664
# 665 Train_665
# 666 Train_666
# 667 Train_667
# 668 Train_668
# 669 Train_669
# 670 Train_670
# 671 Train_671
# 672 Train_672
# 673 Train_673
# 674 Train_674
# 675 Train_675
# 676 Train_676
# 677 Train_677
# 678 Train_678
# 679 Train_679
# 680 Train_680
# 681 Train_681
# 682 Train_682
# 683 Train_683
# 684 Train_684
# 685 Train_685
# 686 Train_686
# 687 Train_687
# 688 Train_688
# 689 Train_689
# 690 Train_690
# 691 Train_691
# 692 Train_692
# 693 Train_693
# 694 Train_694
# 695 Train_695
# 696 Train_696
# 697 Train_697
# 698 Train_698
# 699 Train_699
# 700 Train_700
# 701 Train_701
# 702 Train_702
# 703 Train_703
# 704 Train_704
# 705 Train_705
# 706 Train_706
# 707 Train_707
# 708 Train_708
# 709 Train_709
# 710 Train_710
# 711 Train_711
# 712 Train_712
# 713 Train_713
# 714 Train_714
# 715 Train_715
# 716 Train_716
# 717 Train_717
# 718 Train_718
# 719 Train_719
# 720 Train_720
# 721 Train_721
# 722 Train_722
# 723 Train_723
# 724 Train_724
# 725 Train_725
# 726 Train_726
# 727 Train_727
# 728 Train_728
# 729 Train_729
# 730 Train_730
# 731 Train_731
# 732 Train_732
# 733 Train_733
# 734 Train_734
# 735 Train_735
# 736 Train_736
# 737 Train_737
# 738 Train_738
# 739 Train_739
# 740 Train_740
# 741 Train_741
# 742 Train_742
# 743 Train_743
# 744 Train_744
# 745 Train_745
# 746 Train_746
# 747 Train_747
# 748 Train_748
# 749 Train_749
# 750 Train_750
# 751 Train_751
# 752 Train_752
# 753 Train_753
# 754 Train_754
# 755 Train_755
# 756 Train_756
# 757 Train_757
# 758 Train_758
# 759 Train_759
# 760 Train_760
# 761 Train_761
# 762 Train_762
# 763 Train_763
# 764 Train_764
# 765 Train_765
# 766 Train_766
# 767 Train_767
# 768 Train_768
# 769 Train_769
# 770 Train_770
# 771 Train_771
# 772 Train_772
# 773 Train_773
# 774 Train_774
# 775 Train_775
# 776 Train_776
# 777 Train_777
# 778 Train_778
# 779 Train_779
# 780 Train_780
# 781 Train_781
# 782 Train_782
# 783 Train_783
# 784 Train_784
# 785 Train_785
# 786 Train_786
# 787 Train_787
# 788 Train_788
# 789 Train_789
# 790 Train_790
# 791 Train_791
# 792 Train_792
# 793 Train_793
# 794 Train_794
# 795 Train_795
# 796 Train_796
# 797 Train_797
# 798 Train_798
# 799 Train_799
# 800 Train_800
# 801 Train_801
# 802 Train_802
# 803 Train_803
# 804 Train_804
# 805 Train_805
# 806 Train_806
# 807 Train_807
# 808 Train_808
# 809 Train_809
# 810 Train_810
# 811 Train_811
# 812 Train_812
# 813 Train_813
# 814 Train_814
# 815 Train_815
# 816 Train_816
# 817 Train_817
# 818 Train_818
# 819 Train_819
# 820 Train_820
# 821 Train_821
# 822 Train_822
# 823 Train_823
# 824 Train_824
# 825 Train_825
# 826 Train_826
# 827 Train_827
# 828 Train_828
# 829 Train_829
# 830 Train_830
# 831 Train_831
# 832 Train_832
# 833 Train_833
# 834 Train_834
# 835 Train_835
# 836 Train_836
# 837 Train_837
# 838 Train_838
# 839 Train_839
# 840 Train_840
# 841 Train_841
# 842 Train_842
# 843 Train_843
# 844 Train_844
# 845 Train_845
# 846 Train_846
# 847 Train_847
# 848 Train_848
# 849 Train_849
# 850 Train_850
# 851 Train_851
# 852 Train_852
# 853 Train_853
# 854 Train_854
# 855 Train_855
# 856 Train_856
# 857 Train_857
# 858 Train_858
# 859 Train_859
# 860 Train_860
# 861 Train_861
# 862 Train_862
# 863 Train_863
# 864 Train_864
# 865 Train_865
# 866 Train_866
# 867 Train_867
# 868 Train_868
# 869 Train_869
# 870 Train_870
# 871 Train_871
# 872 Train_872
# 873 Train_873
# 874 Train_874
# 875 Train_875
# 876 Train_876
# 877 Train_877
# 878 Train_878
# 879 Train_879
# 880 Train_880
# 881 Train_881
# 882 Train_882
# 883 Train_883
# 884 Train_884
# 885 Train_885
# 886 Train_886
# 887 Train_887
# 888 Train_888
# 889 Train_889
# 890 Train_890
# 891 Train_891
# 892 Train_892
# 893 Train_893
# 894 Train_894
# 895 Train_895
# 896 Train_896
# 897 Train_897
# 898 Train_898
# 899 Train_899
# 900 Train_900
# 901 Train_901
# 902 Train_902
# 903 Train_903
# 904 Train_904
# 905 Train_905
# 906 Train_906
# 907 Train_907
# 908 Train_908
# 909 Train_909
# 910 Train_910
# 911 Train_911
# 912 Train_912
# 913 Train_913
# 914 Train_914
# 915 Train_915
# 916 Train_916
# 917 Train_917
# 918 Train_918
# 919 Train_919
# 920 Train_920
# 921 Train_921
# 922 Train_922
# 923 Train_923
# 924 Train_924
# 925 Train_925
# 926 Train_926
# 927 Train_927
# 928 Train_928
# 929 Train_929
# 930 Train_930
# 931 Train_931
# 932 Train_932
# 933 Train_933
# 934 Train_934
# 935 Train_935
# 936 Train_936
# 937 Train_937
# 938 Train_938
# 939 Train_939
# 940 Train_940
# 941 Train_941
# 942 Train_942
# 943 Train_943
# 944 Train_944
# 945 Train_945
# 946 Train_946
# 947 Train_947
# 948 Train_948
# 949 Train_949
# 950 Train_950
# 951 Train_951
# 952 Train_952
# 953 Train_953
# 954 Train_954
# 955 Train_955
# 956 Train_956
# 957 Train_957
# 958 Train_958
# 959 Train_959
# 960 Train_960
# 961 Train_961
# 962 Train_962
# 963 Train_963
# 964 Train_964
# 965 Train_965
# 966 Train_966
# 967 Train_967
# 968 Train_968
# 969 Train_969
# 970 Train_970
# 971 Train_971
# 972 Train_972
# 973 Train_973
# 974 Train_974
# 975 Train_975
# 976 Train_976
# 977 Train_977
# 978 Train_978
# 979 Train_979
# 980 Train_980
# 981 Train_981
# 982 Train_982
# 983 Train_983
# 984 Train_984
# 985 Train_985
# 986 Train_986
# 987 Train_987
# 988 Train_988
# 989 Train_989
# 990 Train_990
# 991 Train_991
# 992 Train_992
# 993 Train_993
# 994 Train_994
# 995 Train_995
# 996 Train_996
# 997 Train_997
# 998 Train_998
# 999 Train_999
# 1000 Train_1000
# 1001 Train_1001
# 1002 Train_1002
# 1003 Train_1003
# 1004 Train_1004
# 1005 Train_1005
# 1006 Train_1006
# 1007 Train_1007
# 1008 Train_1008
# 1009 Train_1009
# 1010 Train_1010
# 1011 Train_1011
# 1012 Train_1012
# 1013 Train_1013
# 1014 Train_1014
# 1015 Train_1015
# 1016 Train_1016
# 1017 Train_1017
# 1018 Train_1018
# 1019 Train_1019
# 1020 Train_1020
# 1021 Train_1021
# 1022 Train_1022
# 1023 Train_1023
# 1024 Train_1024
# 1025 Train_1025
# 1026 Train_1026
# 1027 Train_1027
# 1028 Train_1028
# 1029 Train_1029
# 1030 Train_1030
# 1031 Train_1031
# 1032 Train_1032
# 1033 Train_1033
# 1034 Train_1034
# 1035 Train_1035
# 1036 Train_1036
# 1037 Train_1037
# 1038 Train_1038
# 1039 Train_1039
# 1040 Train_1040
# 1041 Train_1041
# 1042 Train_1042
# 1043 Train_1043
# 1044 Train_1044
# 1045 Train_1045
# 1046 Train_1046
# 1047 Train_1047
# 1048 Train_1048
# 1049 Train_1049
# 1050 Train_1050
# 1051 Train_1051
# 1052 Train_1052
# 1053 Train_1053
# 1054 Train_1054
# 1055 Train_1055
# 1056 Train_1056
# 1057 Train_1057
# 1058 Train_1058
# 1059 Train_1059
# 1060 Train_1060
# 1061 Train_1061
# 1062 Train_1062
# 1063 Train_1063
# 1064 Train_1064
# 1065 Train_1065
# 1066 Train_1066
# 1067 Train_1067
# 1068 Train_1068
# 1069 Train_1069
# 1070 Train_1070
# 1071 Train_1071
# 1072 Train_1072
# 1073 Train_1073
# 1074 Train_1074
# 1075 Train_1075
# 1076 Train_1076
# 1077 Train_1077
# 1078 Train_1078
# 1079 Train_1079
# 1080 Train_1080
# 1081 Train_1081
# 1082 Train_1082
# 1083 Train_1083
# 1084 Train_1084
# 1085 Train_1085
# 1086 Train_1086
# 1087 Train_1087
# 1088 Train_1088
# 1089 Train_1089
# 1090 Train_1090
# 1091 Train_1091
# 1092 Train_1092
# 1093 Train_1093
# 1094 Train_1094
# 1095 Train_1095
# 1096 Train_1096
# 1097 Train_1097
# 1098 Train_1098
# 1099 Train_1099
# 1100 Train_1100
# 1101 Train_1101
# 1102 Train_1102
# 1103 Train_1103
# 1104 Train_1104
# 1105 Train_1105
# 1106 Train_1106
# 1107 Train_1107
# 1108 Train_1108
# 1109 Train_1109
# 1110 Train_1110
# 1111 Train_1111
# 1112 Train_1112
# 1113 Train_1113
# 1114 Train_1114
# 1115 Train_1115
# 1116 Train_1116
# %%
print(len(train_label))
print(len(train_data))
train_label[0]
# train_data[0]
# Out:
# 1821
# 1821
# healthy              0
# multiple_diseases    0
# rust                 0
# scab                 1
# Name: 0, dtype: object

# %%
from sklearn.model_selection import train_test_split

train_data_np = np.array(train_data)
train_label_np = np.array(train_label)
(trainX, testX, trainY, testY) = train_test_split(train_data_np, train_label_np,
	test_size=0.25, stratify=train_label_np, random_state=42)

# %%
trainAug = ImageDataGenerator(
	rotation_range=30,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest")
valAug = ImageDataGenerator()

# %%
from keras.applications import VGG16
from keras.layers import Input
baseModel = VGG16(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(128, 128, 3)))

# %%
from keras.layers.pooling import AveragePooling2D
from keras.models import Model
from keras.optimizers import Adam

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(4, activation="softmax")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)
for layer in baseModel.layers:
	layer.trainable = False
print("[INFO] compiling model...")
opt = Adam(lr=1e-2)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
H = model.fit_generator(
	trainAug.flow(trainX, trainY, batch_size=32),
	steps_per_epoch=len(trainX) // 32,
	validation_data=valAug.flow(testX, testY),
	validation_steps=len(testX) // 32,
	epochs=10)
# Out:
# Epoch 1/10
# 42/42 [==============================] - 424s 10s/step - loss: 4.8031 - acc: 0.6727 - val_loss: 5.4030 - val_acc: 0.6629
# Epoch 2/10
# 41/42 [============================>.] - ETA: 7s - loss: 5.4300 - acc: 0.6609
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-578310113cd5> in <module>
#       4         validation_data=valAug.flow(testX, testY),
#       5         validation_steps=len(testX) // 32,
# ----> 6 	epochs=10)
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2193                                 validation_generator,
#    2194                                 validation_steps,
# -> 2195                                 workers=0)
#    2196                         else:
#    2197                             # No need for try/except because
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing)
#    2324                                      'or (x, y). Found: ' +
#    2325                                      str(generator_output))
# -> 2326                 outs = self.test_on_batch(x, y, sample_weight=sample_weight)
#    2327
#    2328                 if isinstance(x, list):
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in test_on_batch(self, x, y, sample_weight)
#    1889             ins = x + y + sample_weights
#    1890         self._make_test_function()
# -> 1891         outputs = self.test_function(ins)
#    1892         if len(outputs) == 1:
#    1893             return outputs[0]
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# c:\users\hphim\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
